# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
# from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

api_key = "3afe54f34c54050cfd01bba01da754a8"
url = 'http://api.openweathermap.org/data/2.5/weather'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Make the API request
        response = requests.get(city_url)
        
        # Check if the request was successful 
        if response.status_code == 200:     
          
            # Parse the JSON and retrieve data
            city_weather = response.json()

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            city_date = city_weather['dt']

            # Append the City information into city_data list
            city_data.append({"City": city, 
                              "Lat": city_lat, 
                              "Lng": city_lng, 
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})

        else:
            print(f"City {city} not found. Skipping...")
            
            
    # If an error is experienced, skip the city
    except Exception as e:
        print(f"Error processing city {city}: {e}")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | estevan
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | puerto natales
# Processing Record 5 of Set 1 | taiohae
# City taiohae not found. Skipping...
# Processing Record 6 of Set 1 | quellon
# Processing Record 7 of Set 1 | moscow
# Processing Record 8 of Set 1 | betare oya
# Processing Record 9 of Set 1 | punto fijo
# Processing Record 10 of Set 1 | waitangi
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | kill devil hills
# Processing Record 13 of Set 1 | port mathurin
# Processing Record 14 of Set 1 | fort bragg
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | touros
# Processing Record 17 of Set 1 | kampar
# Processing Record 18 of Set 1 | edinburgh of the seven seas
# Processing Record 19 of Set 1 | dudinka
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | watford city
# Processing Record 22 of Set 1 | road town
# Processing Record 23 of Set 1 | la sarre
# Processing Record 24 of Set 1 | rabo de peixe
# Processing Record 25 of Set 1 | adamstown
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | utrik
# Processing Record 28 of Set 1 | rajanpur
# Processing Record 29 of Set 1 | biloela
# Processing Record 30 of Set 1 | lautoka
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | dehdasht
# Processing Record 33 of Set 1 | chonchi
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | portland
# Processing Record 36 of Set 1 | college
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | st. john's
# Processing Record 39 of Set 1 | erenhot
# Processing Record 40 of Set 1 | tazovsky
# Processing Record 41 of Set 1 | olonkinbyen
# Processing Record 42 of Set 1 | san antonio de pale
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | isafjordur
# Processing Record 45 of Set 1 | constantia
# Processing Record 46 of Set 1 | ormara
# Processing Record 47 of Set 1 | constitucion
# Processing Record 48 of Set 1 | caucasia
# Processing Record 49 of Set 1 | santa marta
# Processing Record 50 of Set 1 | mirny
# Processing Record 0 of Set 2 | minas de matahambre
# City minas de matahambre not found. Skipping...
# Processing Record 1 of Set 2 | viedma
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | don sak
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | boguchany
# Processing Record 6 of Set 2 | yala
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | isle of lewis
# City isle of lewis not found. Skipping...
# Processing Record 10 of Set 2 | san fernando de apure
# Processing Record 11 of Set 2 | masons bay
# City masons bay not found. Skipping...
# Processing Record 12 of Set 2 | tranovaho
# City tranovaho not found. Skipping...
# Processing Record 13 of Set 2 | pimentel
# Processing Record 14 of Set 2 | hihifo
# City hihifo not found. Skipping...
# Processing Record 15 of Set 2 | hadibu
# Processing Record 16 of Set 2 | papatowai
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | badger
# Processing Record 19 of Set 2 | remire-montjoly
# Processing Record 20 of Set 2 | suva
# Processing Record 21 of Set 2 | labuan
# Processing Record 22 of Set 2 | linxia chengguanzhen
# Processing Record 23 of Set 2 | ampara
# Processing Record 24 of Set 2 | anadyr
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | ibaiti
# Processing Record 27 of Set 2 | saint-martin-des-champs
# Processing Record 28 of Set 2 | ta`u
# Processing Record 29 of Set 2 | sisimiut
# Processing Record 30 of Set 2 | wailua homesteads
# Processing Record 31 of Set 2 | lata
# Processing Record 32 of Set 2 | blackmans bay
# Processing Record 33 of Set 2 | international falls
# Processing Record 34 of Set 2 | flying fish cove
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | granbury
# Processing Record 37 of Set 2 | puerto armuelles
# Processing Record 38 of Set 2 | maragogi
# Processing Record 39 of Set 2 | broome
# Processing Record 40 of Set 2 | marsh harbour
# Processing Record 41 of Set 2 | laguna
# Processing Record 42 of Set 2 | sao vicente
# Processing Record 43 of Set 2 | itupiranga
# Processing Record 44 of Set 2 | posto fiscal rolim de moura
# Processing Record 45 of Set 2 | tolanaro
# Processing Record 46 of Set 2 | moab
# Processing Record 47 of Set 2 | invercargill
# Processing Record 48 of Set 2 | aswan
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 0 of Set 3 | colon
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | tazacorte
# Processing Record 7 of Set 3 | pointe-noire
# Processing Record 8 of Set 3 | vorgashor
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | la passe
# Processing Record 11 of Set 3 | narrabri
# Processing Record 12 of Set 3 | witu
# Processing Record 13 of Set 3 | puerto deseado
# Processing Record 14 of Set 3 | colonia menno
# Processing Record 15 of Set 3 | kapa'a
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | den helder
# Processing Record 18 of Set 3 | amstetten
# Processing Record 19 of Set 3 | basco
# Processing Record 20 of Set 3 | west island
# Processing Record 21 of Set 3 | margaret river
# Processing Record 22 of Set 3 | santana
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | gambiran satu
# Processing Record 25 of Set 3 | nova sintra
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | shwebo
# Processing Record 28 of Set 3 | bhaisa
# Processing Record 29 of Set 3 | labasa
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | hamilton
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | banff
# Processing Record 34 of Set 3 | dhidhdhoo
# Processing Record 35 of Set 3 | ketchikan
# Processing Record 36 of Set 3 | sinop
# Processing Record 37 of Set 3 | metlili chaamba
# Processing Record 38 of Set 3 | usogorsk
# Processing Record 39 of Set 3 | anabar
# City anabar not found. Skipping...
# Processing Record 40 of Set 3 | agri
# Processing Record 41 of Set 3 | hawaiian paradise park
# Processing Record 42 of Set 3 | bilibino
# Processing Record 43 of Set 3 | sinzing
# Processing Record 44 of Set 3 | richards bay
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | colachel
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | medenine
# Processing Record 49 of Set 3 | howrah
# Processing Record 0 of Set 4 | ust-nera
# Processing Record 1 of Set 4 | zeya
# Processing Record 2 of Set 4 | maitum
# Processing Record 3 of Set 4 | hayma'
# City hayma' not found. Skipping...
# Processing Record 4 of Set 4 | betio village
# Processing Record 5 of Set 4 | buenaventura
# Processing Record 6 of Set 4 | xo'jayli shahri
# City xo'jayli shahri not found. Skipping...
# Processing Record 7 of Set 4 | dordrecht
# Processing Record 8 of Set 4 | sinabang
# Processing Record 9 of Set 4 | soto la marina
# Processing Record 10 of Set 4 | happy valley-goose bay
# Processing Record 11 of Set 4 | aripuana
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | bowen
# Processing Record 14 of Set 4 | acarau
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | slave lake
# Processing Record 17 of Set 4 | puerto san carlos
# City puerto san carlos not found. Skipping...
# Processing Record 18 of Set 4 | pangoa
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | rongelap
# Processing Record 22 of Set 4 | den burg
# Processing Record 23 of Set 4 | san francisco de la paz
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | torghay
# Processing Record 26 of Set 4 | marka
# Processing Record 27 of Set 4 | puerto san jose
# Processing Record 28 of Set 4 | atasu
# Processing Record 29 of Set 4 | cannonvale
# Processing Record 30 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | bandeirantes
# Processing Record 33 of Set 4 | coffeyville
# Processing Record 34 of Set 4 | comodoro rivadavia
# Processing Record 35 of Set 4 | bejubang dua
# City bejubang dua not found. Skipping...
# Processing Record 36 of Set 4 | kasempa
# Processing Record 37 of Set 4 | praya
# Processing Record 38 of Set 4 | roma
# Processing Record 39 of Set 4 | fisterra
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | clinton
# Processing Record 43 of Set 4 | burley
# Processing Record 44 of Set 4 | lokossa
# Processing Record 45 of Set 4 | aasiaat
# Processing Record 46 of Set 4 | lobito
# Processing Record 47 of Set 4 | afif
# Processing Record 48 of Set 4 | jhinjhak
# Processing Record 49 of Set 4 | galesong
# Processing Record 0 of Set 5 | gizo
# Processing Record 1 of Set 5 | sandnessjoen
# Processing Record 2 of Set 5 | vadso
# Processing Record 3 of Set 5 | fuvahmulah
# City fuvahmulah not found. Skipping...
# Processing Record 4 of Set 5 | lihue
# Processing Record 5 of Set 5 | prince rupert
# Processing Record 6 of Set 5 | tocache
# Processing Record 7 of Set 5 | weno
# Processing Record 8 of Set 5 | balabac
# Processing Record 9 of Set 5 | kataragama
# City kataragama not found. Skipping...
# Processing Record 10 of Set 5 | amga
# Processing Record 11 of Set 5 | taulaga
# Processing Record 12 of Set 5 | salinopolis
# Processing Record 13 of Set 5 | kihurio
# Processing Record 14 of Set 5 | baotou
# Processing Record 15 of Set 5 | reggane
# Processing Record 16 of Set 5 | el calafate
# Processing Record 17 of Set 5 | priob'ye
# Processing Record 18 of Set 5 | udachny
# Processing Record 19 of Set 5 | mount carmel
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | kani keli
# Processing Record 22 of Set 5 | terrace
# Processing Record 23 of Set 5 | sanghar
# Processing Record 24 of Set 5 | sainte-anne-des-monts
# Processing Record 25 of Set 5 | mulayjah
# Processing Record 26 of Set 5 | mount isa
# Processing Record 27 of Set 5 | ialibu
# Processing Record 28 of Set 5 | beni
# Processing Record 29 of Set 5 | maloyaroslavets
# Processing Record 30 of Set 5 | bardai
# Processing Record 31 of Set 5 | zlatoust
# Processing Record 32 of Set 5 | ryotsu-minato
# Processing Record 33 of Set 5 | jagannathpur
# Processing Record 34 of Set 5 | newman
# Processing Record 35 of Set 5 | yar
# Processing Record 36 of Set 5 | saint peters
# Processing Record 37 of Set 5 | 'ohonua
# City 'ohonua not found. Skipping...
# Processing Record 38 of Set 5 | smara
# Processing Record 39 of Set 5 | langarud
# Processing Record 40 of Set 5 | ahau
# City ahau not found. Skipping...
# Processing Record 41 of Set 5 | sumusta as sultani
# Processing Record 42 of Set 5 | kenai
# Processing Record 43 of Set 5 | klyuchi
# Processing Record 44 of Set 5 | qarqaraly
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | stanley
# Processing Record 47 of Set 5 | hailey
# Processing Record 48 of Set 5 | la'ie
# Processing Record 49 of Set 5 | thunder bay
# Processing Record 0 of Set 6 | bijie
# Processing Record 1 of Set 6 | vilyuchinsk
# Processing Record 2 of Set 6 | nar'yan-mar
# Processing Record 3 of Set 6 | kapit
# Processing Record 4 of Set 6 | mugia
# Processing Record 5 of Set 6 | san luis de la loma
# Processing Record 6 of Set 6 | ngereklmadel
# Processing Record 7 of Set 6 | toga village
# City toga village not found. Skipping...
# Processing Record 8 of Set 6 | nemuro
# Processing Record 9 of Set 6 | zafar
# Processing Record 10 of Set 6 | atafu village
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | buraydah
# Processing Record 13 of Set 6 | horsham
# Processing Record 14 of Set 6 | palikir - national government center
# Processing Record 15 of Set 6 | sao geraldo do araguaia
# Processing Record 16 of Set 6 | cabedelo
# Processing Record 17 of Set 6 | hemsby
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | yeniseysk
# Processing Record 20 of Set 6 | arkhangel'sk
# Processing Record 21 of Set 6 | westport
# Processing Record 22 of Set 6 | tiksi
# Processing Record 23 of Set 6 | albacete
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | papao
# Processing Record 26 of Set 6 | lindsay
# Processing Record 27 of Set 6 | airuk
# Processing Record 28 of Set 6 | al ghayzah
# Processing Record 29 of Set 6 | qamdo
# Processing Record 30 of Set 6 | puerto baquerizo moreno
# Processing Record 31 of Set 6 | shangzhi
# Processing Record 32 of Set 6 | haiku-pauwela
# Processing Record 33 of Set 6 | lexington
# Processing Record 34 of Set 6 | huruta
# Processing Record 35 of Set 6 | mil'kovo
# Processing Record 36 of Set 6 | miles city
# Processing Record 37 of Set 6 | fort st. john
# Processing Record 38 of Set 6 | gilgit
# Processing Record 39 of Set 6 | bamboo flat
# Processing Record 40 of Set 6 | saint-pierre
# Processing Record 41 of Set 6 | yarmouth
# Processing Record 42 of Set 6 | iola
# Processing Record 43 of Set 6 | la mira
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | kotovo
# Processing Record 46 of Set 6 | shahrud
# Processing Record 47 of Set 6 | enewetak
# Processing Record 48 of Set 6 | inarajan village
# Processing Record 49 of Set 6 | funafuti
# Processing Record 0 of Set 7 | dapa
# Processing Record 1 of Set 7 | rumuruti
# Processing Record 2 of Set 7 | riberalta
# Processing Record 3 of Set 7 | bay harbor
# Processing Record 4 of Set 7 | carnarvon
# Processing Record 5 of Set 7 | horad zhodzina
# Processing Record 6 of Set 7 | fale old settlement
# Processing Record 7 of Set 7 | devinuwara
# City devinuwara not found. Skipping...
# Processing Record 8 of Set 7 | mogocha
# Processing Record 9 of Set 7 | yuzhno-kurilsk
# Processing Record 10 of Set 7 | el alto
# Processing Record 11 of Set 7 | ponta delgada
# Processing Record 12 of Set 7 | zarghun shahr
# Processing Record 13 of Set 7 | kudat
# Processing Record 14 of Set 7 | turek
# Processing Record 15 of Set 7 | leiyang
# Processing Record 16 of Set 7 | kralendijk
# Processing Record 17 of Set 7 | vuktyl
# Processing Record 18 of Set 7 | holualoa
# Processing Record 19 of Set 7 | ilha de mocambique
# Processing Record 20 of Set 7 | rosignol
# Processing Record 21 of Set 7 | kovdor
# Processing Record 22 of Set 7 | susuman
# Processing Record 23 of Set 7 | belomorsk
# Processing Record 24 of Set 7 | vredendal
# Processing Record 25 of Set 7 | lafia
# Processing Record 26 of Set 7 | tura
# Processing Record 27 of Set 7 | ust'-ilimsk
# Processing Record 28 of Set 7 | tomatlan
# Processing Record 29 of Set 7 | mikuni
# Processing Record 30 of Set 7 | sarkand
# Processing Record 31 of Set 7 | loreto
# Processing Record 32 of Set 7 | barranca
# Processing Record 33 of Set 7 | raja
# Processing Record 34 of Set 7 | lospalos
# Processing Record 35 of Set 7 | patacamaya
# Processing Record 36 of Set 7 | hammerfest
# Processing Record 37 of Set 7 | lupane
# Processing Record 38 of Set 7 | al 'alamayn
# City al 'alamayn not found. Skipping...
# Processing Record 39 of Set 7 | okha
# Processing Record 40 of Set 7 | nuuk
# Processing Record 41 of Set 7 | wuhai
# Processing Record 42 of Set 7 | santa cruz
# Processing Record 43 of Set 7 | businga
# Processing Record 44 of Set 7 | midvagur
# Processing Record 45 of Set 7 | usinsk
# Processing Record 46 of Set 7 | kristiansund
# Processing Record 47 of Set 7 | mhamid
# Processing Record 48 of Set 7 | afaahiti
# Processing Record 49 of Set 7 | sitia
# Processing Record 0 of Set 8 | wakkanai
# Processing Record 1 of Set 8 | wotho
# Processing Record 2 of Set 8 | at taj
# Processing Record 3 of Set 8 | badiyah
# Processing Record 4 of Set 8 | pampa del indio
# Processing Record 5 of Set 8 | yatou
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | nyurba
# Processing Record 8 of Set 8 | saipan
# Processing Record 9 of Set 8 | telavi
# Processing Record 10 of Set 8 | arraial do cabo
# Processing Record 11 of Set 8 | chissamba
# Processing Record 12 of Set 8 | taltal
# Processing Record 13 of Set 8 | urengoy
# Processing Record 14 of Set 8 | nagqu
# Processing Record 15 of Set 8 | antsiranana
# Processing Record 16 of Set 8 | iwamizawa
# Processing Record 17 of Set 8 | greymouth
# Processing Record 18 of Set 8 | kingston
# Processing Record 19 of Set 8 | port augusta
# Processing Record 20 of Set 8 | slavutych
# Processing Record 21 of Set 8 | minas de marcona
# Processing Record 22 of Set 8 | chegdomyn
# Processing Record 23 of Set 8 | madras
# Processing Record 24 of Set 8 | holbrook
# Processing Record 25 of Set 8 | yamada
# Processing Record 26 of Set 8 | ola
# Processing Record 27 of Set 8 | mishelevka
# Processing Record 28 of Set 8 | punta del este
# Processing Record 29 of Set 8 | leer
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | juneau
# Processing Record 32 of Set 8 | penzance
# Processing Record 33 of Set 8 | kargasok
# Processing Record 34 of Set 8 | chanika
# Processing Record 35 of Set 8 | paraiso
# Processing Record 36 of Set 8 | broken hill
# Processing Record 37 of Set 8 | kambove
# Processing Record 38 of Set 8 | choyr
# Processing Record 39 of Set 8 | mata-utu
# Processing Record 40 of Set 8 | sterling
# Processing Record 41 of Set 8 | sinfra
# Processing Record 42 of Set 8 | prado
# Processing Record 43 of Set 8 | laojunmiao
# Processing Record 44 of Set 8 | beytussebap
# Processing Record 45 of Set 8 | encruzilhada do sul
# Processing Record 46 of Set 8 | benito juarez
# Processing Record 47 of Set 8 | monte maiz
# Processing Record 48 of Set 8 | severo-yeniseyskiy
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 0 of Set 9 | prince george
# Processing Record 1 of Set 9 | tidjikja
# Processing Record 2 of Set 9 | nadi
# Processing Record 3 of Set 9 | revda
# Processing Record 4 of Set 9 | yigo village
# Processing Record 5 of Set 9 | zapata
# Processing Record 6 of Set 9 | pokaran
# Processing Record 7 of Set 9 | naze
# Processing Record 8 of Set 9 | talnakh
# Processing Record 9 of Set 9 | buka
# Processing Record 10 of Set 9 | caras
# Processing Record 11 of Set 9 | bam
# Processing Record 12 of Set 9 | urangan
# Processing Record 13 of Set 9 | salaqi
# Processing Record 14 of Set 9 | ar ruways
# Processing Record 15 of Set 9 | tangalle
# Processing Record 16 of Set 9 | egilsstadir
# Processing Record 17 of Set 9 | grootfontein
# Processing Record 18 of Set 9 | kzyltu
# Processing Record 19 of Set 9 | gisborne
# Processing Record 20 of Set 9 | pionerskiy
# Processing Record 21 of Set 9 | ramapuram
# Processing Record 22 of Set 9 | pemba
# Processing Record 23 of Set 9 | roberval
# Processing Record 24 of Set 9 | ishigaki
# Processing Record 25 of Set 9 | jingling
# Processing Record 26 of Set 9 | mawu
# Processing Record 27 of Set 9 | edson
# Processing Record 28 of Set 9 | chadron
# Processing Record 29 of Set 9 | hilo
# Processing Record 30 of Set 9 | santo antonio
# Processing Record 31 of Set 9 | nguigmi
# Processing Record 32 of Set 9 | gamboru
# Processing Record 33 of Set 9 | kasungu
# Processing Record 34 of Set 9 | emerald
# Processing Record 35 of Set 9 | osorno
# Processing Record 36 of Set 9 | antofagasta
# Processing Record 37 of Set 9 | caldwell
# Processing Record 38 of Set 9 | east london
# Processing Record 39 of Set 9 | howard springs
# Processing Record 40 of Set 9 | opuwo
# Processing Record 41 of Set 9 | bahia blanca
# Processing Record 42 of Set 9 | sunagawa
# Processing Record 43 of Set 9 | novopokrovskaya
# Processing Record 44 of Set 9 | tome
# Processing Record 45 of Set 9 | tatarsk
# Processing Record 46 of Set 9 | itoman
# Processing Record 47 of Set 9 | jayapura
# Processing Record 48 of Set 9 | bayanhongor
# Processing Record 49 of Set 9 | keokuk
# Processing Record 0 of Set 10 | tralee
# Processing Record 1 of Set 10 | morehead
# Processing Record 2 of Set 10 | xiva
# Processing Record 3 of Set 10 | nashtarud
# City nashtarud not found. Skipping...
# Processing Record 4 of Set 10 | pacasmayo
# Processing Record 5 of Set 10 | naracoorte
# Processing Record 6 of Set 10 | bovec
# Processing Record 7 of Set 10 | tonghae
# Processing Record 8 of Set 10 | khanu woralaksaburi
# Processing Record 9 of Set 10 | long beach
# Processing Record 10 of Set 10 | moree
# Processing Record 11 of Set 10 | belyy yar
# Processing Record 12 of Set 10 | dauphin
# Processing Record 13 of Set 10 | khorixas
# Processing Record 14 of Set 10 | talpa de allende
# Processing Record 15 of Set 10 | lamu
# Processing Record 16 of Set 10 | vershino-darasunskiy
# Processing Record 17 of Set 10 | kokopo
# Processing Record 18 of Set 10 | alice springs
# Processing Record 19 of Set 10 | konarka
# Processing Record 20 of Set 10 | grand falls-windsor
# Processing Record 21 of Set 10 | zeerust
# Processing Record 22 of Set 10 | vernon
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | forster
# Processing Record 25 of Set 10 | tobelo
# Processing Record 26 of Set 10 | altai
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | phan thiet
# Processing Record 29 of Set 10 | dassa-zoume
# Processing Record 30 of Set 10 | novyy urgal
# Processing Record 31 of Set 10 | mmabatho
# Processing Record 32 of Set 10 | yemva
# Processing Record 33 of Set 10 | machico
# Processing Record 34 of Set 10 | colonia
# Processing Record 35 of Set 10 | uturoa
# Processing Record 36 of Set 10 | bukama
# Processing Record 37 of Set 10 | nizao
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | pisco
# Processing Record 40 of Set 10 | rosarito
# Processing Record 41 of Set 10 | amos
# Processing Record 42 of Set 10 | beroroha
# Processing Record 43 of Set 10 | illizi
# Processing Record 44 of Set 10 | langepas
# Processing Record 45 of Set 10 | selfoss
# Processing Record 46 of Set 10 | skovorodino
# Processing Record 47 of Set 10 | christchurch
# Processing Record 48 of Set 10 | tanjungtiram
# Processing Record 49 of Set 10 | toamasina
# Processing Record 0 of Set 11 | pyay
# Processing Record 1 of Set 11 | lazaro cardenas
# Processing Record 2 of Set 11 | natal
# Processing Record 3 of Set 11 | vingt cinq
# City vingt cinq not found. Skipping...
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | ancud
# Processing Record 6 of Set 11 | saint-louis du nord
# Processing Record 7 of Set 11 | las higueras
# Processing Record 8 of Set 11 | bugul'ma
# Processing Record 9 of Set 11 | gallivare
# City gallivare not found. Skipping...
# Processing Record 10 of Set 11 | alofi
# Processing Record 11 of Set 11 | mbekenyera
# Processing Record 12 of Set 11 | vila do maio
# Processing Record 13 of Set 11 | nova vicosa
# Processing Record 14 of Set 11 | karukh
# Processing Record 15 of Set 11 | kolondieba
# Processing Record 16 of Set 11 | lhasa
# Processing Record 17 of Set 11 | shenjiamen
# Processing Record 18 of Set 11 | yonggwang-up
# Processing Record 19 of Set 11 | zangguy
# City zangguy not found. Skipping...
# Processing Record 20 of Set 11 | kish
# Processing Record 21 of Set 11 | labytnangi
# Processing Record 22 of Set 11 | al jawf
# Processing Record 23 of Set 11 | saarijarvi
# Processing Record 24 of Set 11 | aykhal
# Processing Record 25 of Set 11 | santiago papasquiaro
# City santiago papasquiaro not found. Skipping...
# Processing Record 26 of Set 11 | yagry
# City yagry not found. Skipping...
# Processing Record 27 of Set 11 | caleta de carquin
# Processing Record 28 of Set 11 | kuanda
# Processing Record 29 of Set 11 | garca
# Processing Record 30 of Set 11 | alotau
# City alotau not found. Skipping...
# Processing Record 31 of Set 11 | tuy hoa
# Processing Record 32 of Set 11 | sechura
# Processing Record 33 of Set 11 | aldan
# Processing Record 34 of Set 11 | benguela
# Processing Record 35 of Set 11 | al khafji
# Processing Record 36 of Set 11 | al bawiti
# Processing Record 37 of Set 11 | bulungu
# Processing Record 38 of Set 11 | colby
# Processing Record 39 of Set 11 | tomarovka
# Processing Record 40 of Set 11 | keflavik
# Processing Record 41 of Set 11 | rabigh
# Processing Record 42 of Set 11 | karasburg
# Processing Record 43 of Set 11 | le port
# Processing Record 44 of Set 11 | iquique
# Processing Record 45 of Set 11 | veymandoo
# City veymandoo not found. Skipping...
# Processing Record 46 of Set 11 | horta
# Processing Record 47 of Set 11 | cockburn town
# Processing Record 48 of Set 11 | sarankhola
# Processing Record 49 of Set 11 | geraldton
# Processing Record 0 of Set 12 | vanimo
# Processing Record 1 of Set 12 | mehdia daira de meghila
# Processing Record 2 of Set 12 | deqen
# Processing Record 3 of Set 12 | xining
# Processing Record 4 of Set 12 | kolonia
# Processing Record 5 of Set 12 | cadale
# Processing Record 6 of Set 12 | taperoa
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | turpan
# Processing Record 9 of Set 12 | north battleford
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | nuku'alofa
# Processing Record 12 of Set 12 | maumere
# Processing Record 13 of Set 12 | rancho palos verdes
# Processing Record 14 of Set 12 | semporna
# Processing Record 15 of Set 12 | peace river
# Processing Record 16 of Set 12 | olovyannaya
# Processing Record 17 of Set 12 | front royal
# Processing Record 18 of Set 12 | budva
# Processing Record 19 of Set 12 | barah
# Processing Record 20 of Set 12 | musafir-khana
# Processing Record 21 of Set 12 | baiao
# Processing Record 22 of Set 12 | beira
# Processing Record 23 of Set 12 | polyarnyy
# Processing Record 24 of Set 12 | pacific grove
# Processing Record 25 of Set 12 | upata
# Processing Record 26 of Set 12 | nekrasovskoye
# Processing Record 27 of Set 12 | auki
# Processing Record 28 of Set 12 | melchor de mencos
# Processing Record 29 of Set 12 | iskateley
# Processing Record 30 of Set 12 | el nido
# Processing Record 31 of Set 12 | coahuayana de hidalgo
# Processing Record 32 of Set 12 | ust-tsilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    278.01        83          76
# 1            estevan  49.1334 -102.9842    266.34        79           0
# 2          ilulissat  69.2167  -51.1000    278.16        45         100
# 3     puerto natales -51.7236  -72.4875    281.49        91         100
# 4            quellon -43.1167  -73.6167    283.19        86          88
#
#    Wind Speed Country        Date
# 0       18.72      TF  1708237441
# 1        4.12      CA  1708237441
# 2        9.26      GL  1708237441
# 3        1.90      CL  1708237441
# 4        2.72      CL  1708237441

# %%
# Scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black', alpha=0.75)

#Set labels and title
plt.title('Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')

#set grid
plt.grid(True)

#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black', alpha=0.75)

#Set labels and title
plt.title('Latitude vs. Max Humidity')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (K)')

#set grid
plt.grid(True)

#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='black', alpha=0.75)

#Set labels and title
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#set grid
plt.grid(True)

#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='black', alpha=0.75)

#Set labels and title
plt.title('Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#set grid
plt.grid(True)

#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Export the City_Data into a csv
# city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
